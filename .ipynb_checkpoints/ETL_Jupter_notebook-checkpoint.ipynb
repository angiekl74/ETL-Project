# %%
import pandas as pd
import datetime as dt
from sqlalchemy import create_engine
import psycopg2

# %%
# DELETE THIS??
# conn = psycopg2.connect(database = "ETL Project", user = 'postgres', 
#  password ='Tashina100!', host = '127.0.0.1', port = '5432')

# %%
engine = create_engine("postgresql://postgres:Tashina100!@localhost:5432/ETL_Project")
conn = engine.connect()

# %%
TSLA_data = pd.read_csv("TSLA.csv")
Tweet_data = pd.read_csv("data_elonmusk_before.csv", encoding='iso-8859-1')

# %%
Tweet_data.head()
# Out:
#   row ID                                              Tweet             Time  \
# 0   Row0  @MeltingIce Assuming max acceleration of 2 to ...  9/29/2017 17:39
# 1   Row1  RT @SpaceX: BFR is capable of transporting sat...  9/29/2017 10:44
# 2   Row2                                     @bigajm Yup :)  9/29/2017 10:39
# 3   Row3                     Part 2 https://t.co/8Fvu57muhM   9/29/2017 9:56
# 4   Row4  Fly to most places on Earth in under 30 mins a...   9/29/2017 9:19
#
#   Retweet from      User
# 0          NaN  elonmusk
# 1       SpaceX  elonmusk
# 2          NaN  elonmusk
# 3          NaN  elonmusk
# 4          NaN  elonmusk

# %%
TSLA_data.head()
# Out:
#      Date  Open_Price  High_Price  Low_Price  Close_Price  Adj_Close_Price  \
# 0  1/2/13   35.000000   35.450001  34.709999    35.360001        35.360001
# 1  1/3/13   35.180000   35.450001  34.750000    34.770000        34.770000
# 2  1/4/13   34.799999   34.799999  33.919998    34.400002        34.400002
# 3  1/7/13   34.799999   34.799999  33.900002    34.340000        34.340000
# 4  1/8/13   34.500000   34.500000  33.110001    33.680000        33.680000
#
#     Volume
# 0  1194800
# 1   742000
# 2   674000
# 3   442000
# 4  1284000

# %%
Tweet_data["Retweet from"].fillna("Not Retweeted", inplace = True)
Tweet_data.head(20)
# Out:
#    row ID                                              Tweet             Time  \
# 0    Row0  @MeltingIce Assuming max acceleration of 2 to ...  9/29/2017 17:39
# 1    Row1  RT @SpaceX: BFR is capable of transporting sat...  9/29/2017 10:44
# 2    Row2                                     @bigajm Yup :)  9/29/2017 10:39
# 3    Row3                     Part 2 https://t.co/8Fvu57muhM   9/29/2017 9:56
# 4    Row4  Fly to most places on Earth in under 30 mins a...   9/29/2017 9:19
# 5    Row5  RT @SpaceX: Supporting the creation of a perma...   9/29/2017 8:57
# 6    Row6  BFR will take you anywhere on Earth in less th...   9/29/2017 8:53
# 7    Row7  Mars City\nOpposite of Earth. Dawn and dusk sk...   9/29/2017 6:03
# 8    Row8            Moon Base Alpha https://t.co/voY8qEW9kl   9/29/2017 5:44
# 9    Row9  Will be announcing something really special at...   9/29/2017 2:36
# 10  Row10  RT @SpaceX: Nine years ago today, Falcon 1 bec...   9/29/2017 2:32
# 11  Row11                                             #NAME?  9/28/2017 22:44
# 12  Row12                                             #NAME?   9/28/2017 7:53
# 13  Row13  RT @mayemusk: .@covergirl I'm so excited to sa...   9/28/2017 7:53
# 14  Row14  Prev ideas for paying ~$10B dev cost incl. Kic...   9/27/2017 3:18
# 15  Row15  Headed to Adelaide soon to describe new BFR pl...   9/27/2017 3:03
# 16  Row16         @El_Deano @Daimler @Jalopnik Yes, I did :)  9/26/2017 15:04
# 17  Row17  Good NYT article from several years ago about ...   9/26/2017 5:39
# 18  Row18                                             #NAME?   9/26/2017 3:13
# 19  Row19  Simulation of how the SpaceX Interplanetary Sp...   9/26/2017 3:11
#
#      Retweet from      User
# 0   Not Retweeted  elonmusk
# 1          SpaceX  elonmusk
# 2   Not Retweeted  elonmusk
# 3   Not Retweeted  elonmusk
# 4   Not Retweeted  elonmusk
# 5          SpaceX  elonmusk
# 6   Not Retweeted  elonmusk
# 7   Not Retweeted  elonmusk
# 8   Not Retweeted  elonmusk
# 9   Not Retweeted  elonmusk
# 10         SpaceX  elonmusk
# 11  Not Retweeted  elonmusk
# 12  Not Retweeted  elonmusk
# 13       mayemusk  elonmusk
# 14  Not Retweeted  elonmusk
# 15  Not Retweeted  elonmusk
# 16  Not Retweeted  elonmusk
# 17  Not Retweeted  elonmusk
# 18  Not Retweeted  elonmusk
# 19  Not Retweeted  elonmusk

# %%
TSLA_data = TSLA_data.rename(columns = {"Open": "open_price", "High":"high_price", "Low":"low_price",
                               "Close":"close_price","Adj Close":"adj_close_price"})

# %%
TSLA_data.dtypes
# Out:
# Date                object
# Open_Price         float64
# High_Price         float64
# Low_Price          float64
# Close_Price        float64
# Adj_Close_Price    float64
# Volume               int64
# dtype: object

# %%
Tweet_data.dtypes
# Out:
# row ID          object
# Tweet           object
# Time            object
# Retweet from    object
# User            object
# dtype: object

# %%
Tweet_data['Date'] = pd.to_datetime(Tweet_data['Time']).dt.date

# %%
Tweet_data.head(30)
# Out:
#    row ID                                              Tweet             Time  \
# 0    Row0  @MeltingIce Assuming max acceleration of 2 to ...  9/29/2017 17:39
# 1    Row1  RT @SpaceX: BFR is capable of transporting sat...  9/29/2017 10:44
# 2    Row2                                     @bigajm Yup :)  9/29/2017 10:39
# 3    Row3                     Part 2 https://t.co/8Fvu57muhM   9/29/2017 9:56
# 4    Row4  Fly to most places on Earth in under 30 mins a...   9/29/2017 9:19
# 5    Row5  RT @SpaceX: Supporting the creation of a perma...   9/29/2017 8:57
# 6    Row6  BFR will take you anywhere on Earth in less th...   9/29/2017 8:53
# 7    Row7  Mars City\nOpposite of Earth. Dawn and dusk sk...   9/29/2017 6:03
# 8    Row8            Moon Base Alpha https://t.co/voY8qEW9kl   9/29/2017 5:44
# 9    Row9  Will be announcing something really special at...   9/29/2017 2:36
# 10  Row10  RT @SpaceX: Nine years ago today, Falcon 1 bec...   9/29/2017 2:32
# 11  Row11                                             #NAME?  9/28/2017 22:44
# 12  Row12                                             #NAME?   9/28/2017 7:53
# 13  Row13  RT @mayemusk: .@covergirl I'm so excited to sa...   9/28/2017 7:53
# 14  Row14  Prev ideas for paying ~$10B dev cost incl. Kic...   9/27/2017 3:18
# 15  Row15  Headed to Adelaide soon to describe new BFR pl...   9/27/2017 3:03
# 16  Row16         @El_Deano @Daimler @Jalopnik Yes, I did :)  9/26/2017 15:04
# 17  Row17  Good NYT article from several years ago about ...   9/26/2017 5:39
# 18  Row18                                             #NAME?   9/26/2017 3:13
# 19  Row19  Simulation of how the SpaceX Interplanetary Sp...   9/26/2017 3:11
# 20  Row20                                             #NAME?  9/25/2017 21:33
# 21  Row21  Major improvements & some unexpected applicati...  9/25/2017 13:15
# 22  Row22  Presentation of @SpaceX Interplanetary Spacesh...  9/25/2017 13:12
# 23  Row23  @USATODAYmoney @NathanBomey That's not a lot o...  9/24/2017 22:31
# 24  Row24  RT @MotorTrend: Shocking winner of our latest,...   9/22/2017 2:31
# 25  Row25  @Its_Subhamk Don't give up if the cause is imp...  9/20/2017 19:25
# 26  Row26                                             #NAME?  9/19/2017 19:36
# 27  Row27                                             #NAME?   9/16/2017 9:16
# 28  Row28  @Bobby_Gupta Def not ok. Just sent a reminder ...   9/16/2017 5:16
# 29  Row29  @rishabagrwl2013 In discussions with national ...   9/16/2017 3:28
#
#      Retweet from      User        Date
# 0   Not Retweeted  elonmusk  2017-09-29
# 1          SpaceX  elonmusk  2017-09-29
# 2   Not Retweeted  elonmusk  2017-09-29
# 3   Not Retweeted  elonmusk  2017-09-29
# 4   Not Retweeted  elonmusk  2017-09-29
# 5          SpaceX  elonmusk  2017-09-29
# 6   Not Retweeted  elonmusk  2017-09-29
# 7   Not Retweeted  elonmusk  2017-09-29
# 8   Not Retweeted  elonmusk  2017-09-29
# 9   Not Retweeted  elonmusk  2017-09-29
# 10         SpaceX  elonmusk  2017-09-29
# 11  Not Retweeted  elonmusk  2017-09-28
# 12  Not Retweeted  elonmusk  2017-09-28
# 13       mayemusk  elonmusk  2017-09-28
# 14  Not Retweeted  elonmusk  2017-09-27
# 15  Not Retweeted  elonmusk  2017-09-27
# 16  Not Retweeted  elonmusk  2017-09-26
# 17  Not Retweeted  elonmusk  2017-09-26
# 18  Not Retweeted  elonmusk  2017-09-26
# 19  Not Retweeted  elonmusk  2017-09-26
# 20  Not Retweeted  elonmusk  2017-09-25
# 21  Not Retweeted  elonmusk  2017-09-25
# 22  Not Retweeted  elonmusk  2017-09-25
# 23  Not Retweeted  elonmusk  2017-09-24
# 24     MotorTrend  elonmusk  2017-09-22
# 25  Not Retweeted  elonmusk  2017-09-20
# 26  Not Retweeted  elonmusk  2017-09-19
# 27  Not Retweeted  elonmusk  2017-09-16
# 28  Not Retweeted  elonmusk  2017-09-16
# 29  Not Retweeted  elonmusk  2017-09-16

# %%
Tweet_data = Tweet_data.rename(columns= {"User": "User_name"})

# %%
Tweet_data.dtypes
# Out:
# row ID          object
# Tweet           object
# Time            object
# Retweet from    object
# User_name       object
# Date            object
# dtype: object

# %%
clean_tweet_data = Tweet_data[["Tweet", "Retweet from", "User_name", "Date"]]

# %%
clean_tweet_data.head()
# Out:
#                                                Tweet   Retweet from User_name  \
# 0  @MeltingIce Assuming max acceleration of 2 to ...  Not Retweeted  elonmusk
# 1  RT @SpaceX: BFR is capable of transporting sat...         SpaceX  elonmusk
# 2                                     @bigajm Yup :)  Not Retweeted  elonmusk
# 3                     Part 2 https://t.co/8Fvu57muhM  Not Retweeted  elonmusk
# 4  Fly to most places on Earth in under 30 mins a...  Not Retweeted  elonmusk
#
#          Date
# 0  2017-09-29
# 1  2017-09-29
# 2  2017-09-29
# 3  2017-09-29
# 4  2017-09-29

# %%
clean_tweet_data["Date"] = pd.to_datetime(clean_tweet_data["Date"])
# Out:
# C:\Users\joe43\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
clean_tweet_data.dtypes
# Out:
# Tweet                   object
# Retweet from            object
# User_name               object
# Date            datetime64[ns]
# dtype: object

# %%
TSLA_data["Date"] = pd.to_datetime(TSLA_data["Date"])

# %%
TSLA_data.dtypes
# Out:
# Date               datetime64[ns]
# Open_Price                float64
# High_Price                float64
# Low_Price                 float64
# Close_Price               float64
# Adj_Close_Price           float64
# Volume                      int64
# dtype: object

# %%
TSLA_data.to_sql("stock", con=conn)
clean_tweet_data.to_sql("tweet", con=conn)
